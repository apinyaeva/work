# %%
# Классический алгоритм Евклида
function euclidean_gcd(a::Int, b::Int)
    a, b = abs(a), abs(b)
    while b != 0
        a, b = b, a % b
    end
    return a
end

# Бинарный алгоритм Евклида
function binary_gcd(a::Int, b::Int)
    a, b = abs(a), abs(b)
    
    a == 0 && return b
    b == 0 && return a
    
    shift = 0
    while iseven(a) && iseven(b)
        a ÷= 2
        b ÷= 2
        shift += 1
    end
    
    while a != 0
        while iseven(a)
            a ÷= 2
        end
        while iseven(b)
            b ÷= 2
        end
        
        if a >= b
            a = a - b
        else
            b = b - a
        end
    end
    
    return b << shift  # b * 2^shift
end

# Расширенный алгоритм Евклида
function extended_euclidean(a::Int, b::Int)
    a, b = abs(a), abs(b)
    
    if b == 0
        return (a, 1, 0)
    end
    
    x0, x1 = 1, 0
    y0, y1 = 0, 1
    
    while b != 0
        q = a ÷ b
        a, b = b, a % b
        x0, x1 = x1, x0 - q * x1
        y0, y1 = y1, y0 - q * y1
    end
    
    return (a, x0, y0)
end

# Расширенный бинарный алгоритм Евклида
function extended_binary_gcd(a::Int, b::Int)
    a, b = abs(a), abs(b)
    
    if a == 0
        return (b, 0, 1)
    elseif b == 0
        return (a, 1, 0)
    end
    
    g = 1
    while iseven(a) && iseven(b)
        a ÷= 2
        b ÷= 2
        g *= 2
    end
    
    u, v = a, b
    A, B, C, D = 1, 0, 0, 1
    
    while u != 0
        while iseven(u)
            u ÷= 2
            if iseven(A) && iseven(B)
                A ÷= 2
                B ÷= 2
            else
                A = (A + b) ÷ 2
                B = (B - a) ÷ 2
            end
        end
        
        while iseven(v)
            v ÷= 2
            if iseven(C) && iseven(D)
                C ÷= 2
                D ÷= 2
            else
                C = (C + b) ÷ 2
                D = (D - a) ÷ 2
            end
        end
        
        if u >= v
            u -= v
            A -= C
            B -= D
        else
            v -= u
            C -= A
            D -= B
        end
    end
    
    d = g * v
    return (d, C, D)
end
# Out:
# extended_binary_gcd (generic function with 1 method)

# %%
function test_algorithms()
    test_cases = [
        (54, 24),
        (12345, 24690),
        (12345, 54321),
        (12345, 12541),
        (91, 105),
        (105, 154),
        (17, 13),  # Простые числа
        (100, 25), # Одно делит другое
        (0, 15),   # Ноль
        (15, 0),   # Ноль
        (-54, 24), # Отрицательные числа
        (54, -24)  # Отрицательные числа
    ]
    
    println("ТЕСТИРОВАНИЕ АЛГОРИТМОВ НОД")
    println("="^50)
    
    for (i, (a, b)) in enumerate(test_cases)
        println("\nТест $i: НОД($a, $b)")
        println("-"^30)
        
        # Алгоритм Евклида
        gcd1 = euclidean_gcd(a, b)
        println("Алгоритм Евклида: $gcd1")
        
        # Бинарный алгоритм
        gcd2 = binary_gcd(a, b)
        println("Бинарный алгоритм: $gcd2")
        
        # Расширенный алгоритм
        gcd3, x3, y3 = extended_euclidean(a, b)
        println("Расширенный алгоритм: $gcd3")
        println("Коэффициенты Безу: $a×$x3 + $b×$y3 = $(a*x3 + b*y3)")
        
        # Расширенный бинарный алгоритм
        gcd4, x4, y4 = extended_binary_gcd(a, b)
        println("Расшир. бинарный: $gcd4")
        println("Коэффициенты Безу: $a×$x4 + $b×$y4 = $(a*x4 + b*y4)")
        
        # Проверка согласованности
        if gcd1 == gcd2 == gcd3 == gcd4
            println("✓ Все алгоритмы дали одинаковый результат")
        else
            println("✗ Ошибка: результаты различаются!")
        end
        
        # Проверка взаимной простоты
        if gcd1 == 1
            println("✓ Числа взаимно просты")
        else
            println("Числа не взаимно просты")
        end
    end
end
# Out:
# test_algorithms (generic function with 1 method)

# %%
function main()
    
    println()
    
    test_algorithms()  
end
main()
# Out:
# ТЕСТИРОВАНИЕ АЛГОРИТМОВ НОД
# ==================================================
#
# Тест 1: НОД(54, 24)
# ------------------------------
# Алгоритм Евклида: 6
# Бинарный алгоритм: 6
# Расширенный алгоритм: 6
# Коэффициенты Безу: 54×1 + 24×-2 = 6
# Расшир. бинарный: 6
# Коэффициенты Безу: 54×9 + 24×-20 = 6
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
#
# Тест 2: НОД(12345, 24690)
# ------------------------------
# Алгоритм Евклида: 12345
# Бинарный алгоритм: 12345
# Расширенный алгоритм: 12345
# Коэффициенты Безу: 12345×1 + 24690×0 = 12345
# Расшир. бинарный: 12345
# Коэффициенты Безу: 12345×12345 + 24690×-6172 = 12345
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
#
# Тест 3: НОД(12345, 54321)
# ------------------------------
# Алгоритм Евклида: 3
# Бинарный алгоритм: 3
# Расширенный алгоритм: 3
# Коэффициенты Безу: 12345×3617 + 54321×-822 = 3
# Расшир. бинарный: 3
# Коэффициенты Безу: 12345×-14490 + 54321×3293 = 3
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
#
# Тест 4: НОД(12345, 12541)
# ------------------------------
# Алгоритм Евклида: 1
# Бинарный алгоритм: 1
# Расширенный алгоритм: 1
# Коэффициенты Безу: 12345×4159 + 12541×-4094 = 1
# Расшир. бинарный: 1
# Коэффициенты Безу: 12345×4159 + 12541×-4094 = 1
# ✓ Все алгоритмы дали одинаковый результат
# ✓ Числа взаимно просты
#
# Тест 5: НОД(91, 105)
# ------------------------------
# Алгоритм Евклида: 7
# Бинарный алгоритм: 7
# Расширенный алгоритм: 7
# Коэффициенты Безу: 91×7 + 105×-6 = 7
# Расшир. бинарный: 7
# Коэффициенты Безу: 91×52 + 105×-45 = 7
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
#
# Тест 6: НОД(105, 154)
# ------------------------------
# Алгоритм Евклида: 7
# Бинарный алгоритм: 7
# Расширенный алгоритм: 7
# Коэффициенты Безу: 105×3 + 154×-2 = 7
# Расшир. бинарный: 7
# Коэффициенты Безу: 105×113 + 154×-77 = 7
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
#
# Тест 7: НОД(17, 13)
# ------------------------------
# Алгоритм Евклида: 1
# Бинарный алгоритм: 1
# Расширенный алгоритм: 1
# Коэффициенты Безу: 17×-3 + 13×4 = 1
# Расшир. бинарный: 1
# Коэффициенты Безу: 17×-3 + 13×4 = 1
# ✓ Все алгоритмы дали одинаковый результат
# ✓ Числа взаимно просты
#
# Тест 8: НОД(100, 25)
# ------------------------------
# Алгоритм Евклида: 25
# Бинарный алгоритм: 25
# Расширенный алгоритм: 25
# Коэффициенты Безу: 100×0 + 25×1 = 25
# Расшир. бинарный: 25
# Коэффициенты Безу: 100×0 + 25×1 = 25
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
#
# Тест 9: НОД(0, 15)
# ------------------------------
# Алгоритм Евклида: 15
# Бинарный алгоритм: 15
# Расширенный алгоритм: 15
# Коэффициенты Безу: 0×0 + 15×1 = 15
# Расшир. бинарный: 15
# Коэффициенты Безу: 0×0 + 15×1 = 15
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
#
# Тест 10: НОД(15, 0)
# ------------------------------
# Алгоритм Евклида: 15
# Бинарный алгоритм: 15
# Расширенный алгоритм: 15
# Коэффициенты Безу: 15×1 + 0×0 = 15
# Расшир. бинарный: 15
# Коэффициенты Безу: 15×1 + 0×0 = 15
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
#
# Тест 11: НОД(-54, 24)
# ------------------------------
# Алгоритм Евклида: 6
# Бинарный алгоритм: 6
# Расширенный алгоритм: 6
# Коэффициенты Безу: -54×1 + 24×-2 = -102
# Расшир. бинарный: 6
# Коэффициенты Безу: -54×9 + 24×-20 = -966
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
#
# Тест 12: НОД(54, -24)
# ------------------------------
# Алгоритм Евклида: 6
# Бинарный алгоритм: 6
# Расширенный алгоритм: 6
# Коэффициенты Безу: 54×1 + -24×-2 = 102
# Расшир. бинарный: 6
# Коэффициенты Безу: 54×9 + -24×-20 = 966
# ✓ Все алгоритмы дали одинаковый результат
# Числа не взаимно просты
